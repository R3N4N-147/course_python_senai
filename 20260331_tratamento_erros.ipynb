# %%
## Tratamento de Erros
## Try e except

# %%
fruits = ['apple', 'banana', 'cherry']

x = fruits.index("cherry")
print(x)
# Out:
# 2

# %%
fruits = ['strawberry', 'raspberry', 'blueberry']

print(fruits.index("raspberry"))
# Out:
# 1

# %%
try:
  numerador, denominador = float(input("n: ")),float(input("deno: "))
  print(f"Resultado: {numerador/denominador}")
except ValueError:
  print("Valor precisa ser um float")
except ZeroDivisonError:
  print("Não pode dividir por 0")
except:
  print("Não sei qual erro, porém deu erro...")
# Out:
# n: 2
# deno: 5
# Resultado: 0.4

# %%
## Eu gosto de testar algumas coisas antes pq se eu sei qual seria o comportameno

try: # Tente executar o seguinte código
    print('texto'.index('f'))
except: # Se houver erros faça o seguinte código
    print('caractere não encontrado')
# Out:
# caractere não encontrado

# %%
try:
		b = int(input("Digite um número que será dividido por dois"))
		a = b/2
		print(a)
except:
		print('Erro.')
# Out:
# Digite um número que será dividido por dois 55
# 27.5

# %%
try:
    a = 2/'s'
except TypeError:
		# Aqui, o erro é causado por um erro de digitação.
    print('O valor não é um número inteiro.')
except ZeroDivisionError:
		# Aqui, o erro é causado pela divisão por zero.
    print('O valor não pode ser dividido por zero.')
# Out:
# O valor não é um número inteiro.

# %%
try:
    a = 2/(input(""))
except TypeError:
		# Aqui, o erro é causado por um erro de digitação.
    print('O valor não é um número inteiro.')
except ZeroDivisionError:
		# Aqui, o erro é causado pela divisão por zero.
    print('O valor não pode ser dividido por zero.')
# Out:
#  0
# O valor não é um número inteiro.

# %%
## TESTE ALEATORIO
nome = "Renan da Fonseca"
print(f"nome[0:]: {nome[0:]}")
print(f"nome[:]: {nome[:]}")
print(f"nome[:len(nome)]: {nome[:len(nome)]}")
print(f"nome[1:len(nome)]: {nome[1:len(nome)]}")
## print(nome[-len(nome):0]) ## Nao printa nada
## print(nome.reverse()) ## Nao

print(f"\nnome[::-1]: {nome[::-1]}")
# Out:
# nome[0:]: Renan da Fonseca
# nome[:]: Renan da Fonseca
# nome[:len(nome)]: Renan da Fonseca
# nome[1:len(nome)]: enan da Fonseca
#
# nome[::-1]: acesnoF ad naneR

# %%
## TEST ##

''. # <- faça isso + press TAB
''. # <- faça isso + press TAB

# %%
try:
    a = 2/'s'
except TypeError:
		# Aqui o erro não só especificado, como também causado pelo raise Exception.
    raise Exception('O valor não é um número inteiro.')
except ZeroDivisionError:
    print('O valor não pode ser dividido por zero.')
except:
		#Você também pode ter um except vazio para caso não seja nenhum dos erros que você anteviu
    print('O valor não é um número inteiro.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 try:
# ----> 2     a = 2/'s'
#       3 except TypeError:
#       4 		# Aqui o erro não só especificado, como também causado pelo raise Exception.
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2     a = 2/'s'
#       3 except TypeError:
#       4 		# Aqui o erro não só especificado, como também causado pelo raise Exception.
# ----> 5     raise Exception('O valor não é um número inteiro.')
#       6 except ZeroDivisionError:
#       7     print('O valor não pode ser dividido por zero.')
#
# Exception: O valor não é um número inteiro.
