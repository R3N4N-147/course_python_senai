# %%
## Estruturas de Condição

# %%
idade = int(input("Insira sua idade: "))

if idade >= 16:
	print("Você já pode votar.") #esse print está dentro do if
	print(2) #este print ainda está dentro do if
print(3) #já esse saiu da indentação, logo, não pertence ao if

# Se a idade inserida for maior ou igual a 16, logo, o programa informa que o usuário pode votar.
# Out:
# Você já pode votar.
# 2
# 3

# %%
idade = int(input("Insira sua idade: "))

if idade < 16:
	print("Você não pode votar.")
else:
	print("Você já pode votar.")

# Se a idade inserida for menor que 16, logo, o programa informa que o usuário não pode votar.
# Caso contrário, o programa informa ao usuário que ele pode votar.
# Out:
# Você já pode votar.

# %%
# **0.** Verifique se um aluno pode fazer curso técnico no senai (idade mínima 16 anos).
# Desafio: Utilize somente if, não else, e informe, também, caso ele NÃO possa fazer o curso.
# Exemplo: “O aluno <nome> pode se matricular no curso técnico do senai”
# Ou
# “O aluno <nome> não pode se matricular no curso técnico do senai”

nome,idade = input("Qual o NOME do aluno?"),int(input("Qual a IDADE do aluno?"))

if idade >= 16:
    print("O aluno {} pode se matricular no curso técnico do senai.".format(nome))
if idade < 16:
    print("O aluno {} NÃO pode se matricular no curso técnico do senai.".format(nome))
# Out:
# Qual o NOME do aluno? Renan
# Qual a IDADE do aluno? 15
# O aluno Renan NÃO pode se matricular no curso técnico do senai.

# %%
# **1.** Crie um programa que, pergunte a nota de um aluno e verifique se ele passou na nota de corte (acima de 50)
# *Dados: Perguntar ao usuário.*
nota = int(input("Qual a NOTA do aluno?"))
if nota > 50:
    print("Nota {}, ACIMA da nota de corte.".format(nota))
if nota <= 50:
    print("Nota {}, ABAIXO da nota de corte.".format(nota))
# Out:
# Qual a NOTA do aluno? 75
# Nota 75, ACIMA da nota de corte.

# %%
# **1.** (OUTRA SOLUÇÃO)
nota = int(input("Qual a NOTA do aluno?"))
if nota > 50:
    print("Passou")
else:
    print("Não passou")
# Out:
# Qual a NOTA do aluno? 45
# Não passou

# %%
# **2.** Pergunte o salário de um funcionário qualquer e verifique se ele paga imposto de renda.
# *Dados: Pesquise no google a tabela de imposto de renda.*

sal = float(input("Informe o salário. Use ponto para separar os centavos."))
if sal <= 2428.80:
    print("Salario R${:.2f}, aliquota: Isento.".format(sal))
if sal >= 2428.81 and sal <= 2826.65:
    print("Salario R${:.2f}, aliquota: 7.5%.".format(sal))
if sal >= 2826.26 and sal <= 3751.05:
    print("Salario R${:.2f}, aliquota: 15%.".format(sal))
if sal >= 3751.06 and sal <= 4664.68:
    print("Salario R${:.2f}, aliquota: 22.5%.".format(sal))
if sal > 4664.68:
    print("Salario R${:.2f}, aliquota: 27.5%.".format(sal))
# Out:
# Informe o salário. Use ponto para separar os centavos. 4700
# Salario R$4700.00, aliquota: 27.5%.

# %%
# **3.** Crie um programa que decida se um vendedor irá receber um bônus. Para que o vendedor receba o bônus,
# é necessário que tanto ele como a sua empresa tenham batido suas respectivas metas e, caso ele consiga dobrar a meta,
# ele recebe 20% de bônus ao invés dos 10% padrão.
# *Dados: A meta de vendas da empresa é de R$ 200.000,00, e a meta de vendas do funcionário é de R$ 15.000,00.*

vendas,empresa = float(input("Informe as vendas do funcionario.")),float(input("Informe as vendas da empresa."))

if vendas >= 15000.00 and empresa >= 200000.00:
    if vendas >= 30000.00:
        print("Bonus do vendedor: 20%.")
    if vendas <= 30000.00:
        print("Bonus do vendedor: 10%.")
else:
    print("Abaixo da meta.")
# Out:
# Informe as vendas do funcionario. 16000
# Informe as vendas da empresa. 210000
# Bonus do vendedor: 10%.

# %%
# 4. Escreva um programa que pergunte a nota de um aluno. Dada as ranges de conceitos, dê as seguintes respostas:
# < 20: Reprovado ; < 40 Rec 1 ; < 50 Rec 2 ; ≥ 50 Aprovado.
nota = float(input("Insira a nota do aluno:"))
if nota >= 50:
    print("Aprovado")
if nota < 50 and nota >= 40:
    print("Rec 2")
if nota < 40 and nota >= 20:
    print("Rec 1")
if nota < 20:
    print("Reprovado")
# Out:
# Insira a nota do aluno: 95
# Aprovado

# %%
# Fixação: Aprendendo o real significado dos else ifs:
# Crie um script simples que mostre:
# 1:
# Solução 1 para valores informados até 100
# Solução 2 para valores informados até 200
# Solução 3 para valores informados até 300
# Solução 4 para valores informados até 400
# Solução 5 para valores informados até 500

num = int(input("Informe um numero inteiro até 500"))

if num <= 100:
    print("Solução 1")
if num > 100 and num <= 200:
    print("Solução 2")
if num > 200 and num <= 300:
    print("Solução 3")
if num > 300 and num <= 400:
    print("Solução 4")
if num > 400 and num <= 500:
    print("Solução 5")
if num > 500:
    print("Fora das soluções propostas")
# Out:
# Informe um numero inteiro até 500 350
# Solução 4

# %%
# Fixação: Aprendendo o real significado dos else ifs:
# Crie um script simples que mostre:
# 2:
# Solução 1 para valor informado A
# Solução 2 para valor informado B
# Solução 3 para valor informado C
# Solução 4 para valor informado D
# Solução 5 para valor informado E
letra = input("Escolha entre: A, B, C, D, E")
if letra == 'A':
    print("Solução 1")
if letra == 'B':
    print("Solução 2")
if letra == 'C':
    print("Solução 3")
if letra == 'D':
    print("Solução 4")
if letra == 'E':
    print("Solução 5")
else:
    print("Fora das soluções propostas")
# Out:
# Escolha entre: A, B, C, D, E c
# Fora das soluções propostas

# %%
# Fixação: Aprendendo o real significado dos else ifs:
# Crie um script simples que mostre:
# 3:
# Solução 1 caso o valor contenha A
# Solução 2 caso o valor contenha B e não A
# Solução 3 caso o valor contenha C e não A ou B
# Solução 4 caso o valor contenha D e não A ou B ou C
# Solução 5 caso o valor contenha E e não A ou B ou C ou D

## Esse ex me trouxe algumas duvidas
## Enunciado diz SIMPLES, então vou focar em uma solução pontual para cada solução proposta.
## Vou supor o ideal onde o usuario nao erraria e nem tentaria passar a perna no sistema...

s = input("Insira o teste usando: A, B, C, D e E, conforme casos.")
## Descer em cascata eliminando a verificação anterior
## sem usar a ferramenta 'in' seria muito mais complexo...

if 'A' in s: ## Aceita A e todos
    print("{}: Solução 1".format(s))
else: ## Sem A
    if 'B' in s:
        print("{}: Solução 2".format(s))
    else: ## sem A ou B
        if 'C' in s:
            print("{}: Solução 3".format(s))
        else: ## sem A ou B ou C
            if 'D' in s:
                print("{}: Solução 4".format(s))
            else: ## sem A ou B ou C ou D
                if 'E' in s:
                    print("{}: Solução 5".format(s))
# Out:
# Insira o teste usando: A, B, C, D e E, conforme casos. DBA
# DBA: Solução 1

# %%
# **5.** O programa deve: responder se o aluno foi aprovado.
# Receber os dados de um aluno que será do senai vila alpina ou do mooca.
# Se ele for do senai vila alpina, no curso de python ele deve ter pelo menos 60 de nota e 75% de frequência.
# Se ele for do senai mooca, também do curso de python, ele deve ter a mesma quantidade de presença porém
# com uma nota de 50 ele já consegue ser aprovado.
# *Dados: O curso possui 80 aulas. Input: número de faltas*

un = input("Curso Python. Informe a unidade SENAI informando a LETRA + enter. (V: Vila Alpina. M: Mooca)")
grade = float(input("Informe a nota final do aluno."))
freq = int(input("Informe a quantidade de aulas em que o aluno faltou. (Use números inteiros)"))
aulas = 80

if un == "V":
    if grade >= 60 and freq >= aulas*0.75:
        print("Aprovado")
if un == "M":
    if grade >= 50 and freq >= aulas*0.75:
        print("Aprovado")
else:
    print("Reprovado")
# Out:
# Curso Python. Informe a unidade SENAI informando a LETRA + enter. (V: Vila Alpina. M: Mooca) V
# Informe a nota final do aluno. 55
# Informe a quantidade de aulas em que o aluno faltou. (Use números inteiros) 65
# Reprovado

# %%
# 5. (melhorado)
un = input("Curso Python. Senai Unidade V ou M? (V: Vila Alpina. M: Mooca)")
grade = float(input("Informe a nota final do aluno."))
freq = int(input("Informe a quantidade de aulas em que o aluno faltou. (Use números inteiros)"))
aulas = 80

if freq < aulas*0.75: ## Requisito de eliminação para ambos
    if un == "M" and grade >= 50: ## requisitos de eliminação individuais
        print("Aprovado")
    if un == "V" and grade >= 60: ## requisitos de eliminação individuais
        print("Aprovado")
    else:
        print("Reprovado. Nota insuficiente.")
else:
    print("Reprovado por baixa frequencia.")
# Out:
# Curso Python. Senai Unidade V ou M? (V: Vila Alpina. M: Mooca) V
# Informe a nota final do aluno. 50
# Informe a quantidade de aulas em que o aluno faltou. (Use números inteiros) 0
# Reprovado. Nota insuficiente.

# %%
6. # Faça um programa que retorne o servidor do email do usuário, vocês precisam avisar caso não tenha @ no endereço do
# email que o usuário deve digitar um e-mail válido.

email = input("informe seu email.")

if "@" in email:
    posicao = email.index("@") ## index é uma funcao que retorna a posicao de algo (contagem inicia no 0)
    print("@ na posicao: {}".format(posicao))
    print(email[posicao+1:]) ## posicao encontrada + 1. ":" sigfinica vá ate o fim da string
else:
    print("email no formato invalido. '@' não encontrado. Tente novamente.")## De certa forma nem precisava.
# Out:
# informe seu email. renan.fsc@outlook.com
# @ na posicao: 9
# outlook.com

# %%
# 7. Imagine que você está numa escola. Diga se o aluno está aprovado se:
# a) A nota dele for maior ou igual a 50.
# a.a) Faça também para notas superiores a 30, ser possível fazer uma recuperação.
# b) A nota dele for maior ou igual a 50 e a sua frequência superior a 75% da quantidade de horas de curso
# c) A nota dele for superior a 70 (caso seja inferior a 30 assuma que ele está reprovado, entre 30 e 50 está de recuperação
# e acima de 50 até 70 está de exame).
# E também, se for da escola HRC ele precisa ter 50% de frequência.
# Se for de outra escola, 40%.
# Nome ,  Nota  ,  Quantidade de horas do curso (h)   ,   Faltas (h)

escola7 = input("Informe o nome da escola (HRC ou outra)")
nota7 = float(input("Informe a nota final do aluno"))
hora7 = int(input("Informe o quantidade de horas do curso"))
falta7 = int(input("Informe o total de faltas em horas."))

print("\nDiga se o aluno está aprovado se:\n")
print("Ex.7.a: A nota dele for maior ou igual a 50.")
print("Ex.7.a.a: Faça também para notas superiores a 30, ser possível fazer uma recuperação.")

if nota7 > 30:
    if nota7 >= 50:
        print("Aprovado")
    if nota7 < 50 and nota7 > 30:
        print("Recuperacao")
if nota7 <= 30:
    print("Reprovado")

print("\nEx.7.b: A nota dele for maior ou igual a 50 e a sua frequência superior a 75% da quantidade de horas de curso")
if nota7 >= 50 and (hora7-falta7) > hora7*0.75:
    print("Aprovado.")
else:
    print("Reprovado.")

print("\nEx.7.c: A nota dele for superior a 70 \n(caso seja inferior a 30 assuma que ele está reprovado,")
print("\nentre 30 e 50 está de recuperação e \nacima de 50 até 70 está de exame).")
print("\nE também, se for da escola HRC ele precisa ter 50% de freq. Se for outra esccola, 40%.")

if escola7 = "HRC":
    if (hora7-falta7) > hora7*0.50:
        if nota7 > 70:
            print("Aprovado")
        if nota7 <= 70 and nota7 > 50:
            print("Exame")
        if nota7 <= 50 and nota7 >= 30:
            print("Recuperacao")
        if nota7 < 30:
            print("Reprovado")
    else:
        print("Reprovado por frequencia. Menor 50%")
else: ## outras
    if (hora7-falta7) > hora7*0.40:
        if nota7 > 70:
            print("Aprovado")
        if nota7 <= 70 and nota7 > 50:
            print("Exame")
        if nota7 <= 50 and nota7 >= 30:
            print("Recuperacao")
        if nota7 < 30:
            print("Reprovado")
    else:
        print("Reprovado por frequencia. Menor 40%")
# Out:
# Informe o nome da escola 71
# Informe a nota final do aluno 71
# Informe o quantidade de horas do curso 350
# Informe o total de faltas em horas. 5
# Diga se o aluno está aprovado se:
# Exercicio 7.a: A nota dele for maior ou igual a 50.
# Exercicio 7.a.a: Faça também para notas superiores a 30, ser possível fazer uma recuperação.
# Aprovado
#
# Ex.7.b: A nota dele for maior ou igual a 50 e a sua frequência superior a 75% da quantidade de horas de curso
#
# Ex.7.c: A nota dele for superior a 70
# (caso seja inferior a 30 assuma que ele está reprovado,
# entre 30 e 50 está de recuperação e
# acima de 50 até 70 está de exame).
# Aprovado

# %%
# 8. A partir de três números informados pelo usuário, informe a ordem crescente deles
# utilizando somente estruturas de condição.

n0 = 0
n1 = int(input(f"Informe n1 (números inteiros)."))
n2 = int(input(f"Informe n2 (números inteiros)."))
n3 = int(input(f"Informe n3 (números inteiros)."))

print(f"\nn1: {n1} n2: {n2} n3: {n3}")
if n1 > n2:
    n0 = n2
    n2 = n1
    n1 = n0
if n2 > n3:
    n0 = n3
    n3 = n2
    n2 = n0
if n1 > n3:
    n0 = n3
    n3 = n1
    n1 = n0
if n1 > n2:
    n0 = n2
    n2 = n1
    n1 = n0
print("Sorteando: . . .")
print(f"n1: {n1} n2: {n2} n3: {n3}")
# Out:
# Informe n1 (números inteiros). 40
# Informe n2 (números inteiros). 50
# Informe n3 (números inteiros). 60
# n1: 40 n2: 50 n3: 60
# Sorteando: . . .
# n1: 40 n2: 50 n3: 60

# %%
# se n1 > n2
# n0 = n2
# n2 = n1
# n1 = n0

# se n2 > n3
# n0 = n3
# n3 = n2
# n2 = n0

# se não
# imprime n1 n2 n3

# %%
## Match, Case

# %%
n = int(input("Qual o número do mês aniversario: "))
match n:
  case 1:
    print("signo 1")
  case 2:
    print("signo 2")
  case 3:
    print("signo 3")
  case 4:
    print("signo 4")
  case 5:
    print("signo 5")
  case 6:
    print("signo 6")
  case 7:
    print("signo 7")
  case 8:
    print("signo 8")
  case 9:
    print("signo 9")
  case 10:
    print("signo 10")
  case 11:
    print("signo 11")
  case 12:
    print("signo 12")
  case _:
    print("signo _")
# Out:
# Qual o número do mês aniversario: 4
# signo 4

# %%
data = input("Digite sua data de nascimento (dd/mm/aaaa): ") #string

# split() é um método de strings em python, serve: quebrar uma string em várias partes, usando um separador.
dia, mes, ano = data.split("/") # Isso é uma string, atenção com o tipo trabalhado.
dia = int(dia)
mes = int(mes)

# logica: cada mes tem 2 signos, o range do dia diz qual signo.
match mes:
    case 1:
        if dia <= 20:
            signo = "Capricórnio"
        else:
            signo = "Aquário"
    case 2:
        if dia <= 18:
            signo = "Aquário"
        else:
            signo = "Peixes"
    case 3:
        if dia <= 20:
            signo = "Peixes"
        else:
            signo = "Áries"
    case 4:
        if dia <= 20:
            signo = "Áries"
        else:
            signo = "Touro"
    case 5:
        if dia <= 20:
            signo = "Touro"
        else:
            signo = "Gêmeos"
    case 6:
        if dia <= 20:
            signo = "Gêmeos"
        else:
            signo = "Câncer"
    case 7:
        if dia <= 22:
            signo = "Câncer"
        else:
            signo = "Leão"
    case 8:
        if dia <= 22:
            signo = "Leão"
        else:
            signo = "Virgem"
    case 9:
        if dia <= 22:
            signo = "Virgem"
        else:
            signo = "Libra"
    case 10:
        if dia <= 22:
            signo = "Libra"
        else:
            signo = "Escorpião"
    case 11:
        if dia <= 21:
            signo = "Escorpião"
        else:
            signo = "Sagitário"
    case 12:
        if dia <= 21:
            signo = "Sagitário"
        else:
            signo = "Capricórnio"
    case _:
        signo = "Invalido."

print("Seu signo é:", signo)
# Out:
# Digite sua data de nascimento (dd/mm/aaaa): 05/13/2000
# Seu signo é: Invalido.
