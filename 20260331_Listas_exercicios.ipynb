# %%
## Listas[] -> Exercicios para manipular listas[]

# %%
# 1.  Faça um código que: Crie uma lista com 3 nomes.
lista_com_tres_nomes = ["Uguinho","Zezinho", "Luizinho"]

# %%
# 1. Lista vazia
Lista1 = []
Lista1.append("Lulu")
Lista1.append("Lala")
Lista1.append("Lili")
print(Lista1)
# Out:
# ['Lulu', 'Lala', 'Lili']

# %%
# 1.1 Crie uma lista vazia e adicione 4 nomes digitados pelo usuário.
Lista1a = []
Lista1a.append(input(f"Nome 1:"))
Lista1a.append(input(f"Nome 2:"))
Lista1a.append(input(f"Nome 3:"))
Lista1a.append(input(f"Nome 4:"))
Lista1b = Lista1a
print(Lista1a)
# Out:
# Nome 1: um
# Nome 2: dois
# Nome 3: tres
# Nome 4: quatro
# ['um', 'dois', 'tres', 'quatro']

# %%
nomes_teste_imput = [input("nome: "), input("nome: "), input("nome: ")]
print(nomes_teste_imput)
# Out:
# nome: R1
# nome: R2
# nome: R3
# ['R1', 'R2', 'R3']

# %%
# 1.2 A partir da lista anterior, peça um nome ao usuário e, caso ele esteja presente na lista, exclua-o.
## Atencao ao reaproveitar a variavel da secao (linha) anterior na secao (linha) atual.
print(Lista1b)
x = input("Informe um nome: ")
if x in Lista1b:
    Lista1b.remove(x)
    print(F"'{x}' foi removido, sua lista agora é: {Lista1b}")
else:
    print("Nothing to see here.")
    print(f"Just kidding. Here is your list: {Lista1b}")
# Out:
# ['um', 'dois', 'tres', 'quatro']
# Informe um nome:  tres
# 'tres' foi removido, sua lista agora é: ['um', 'dois', 'quatro']

# %%
# 1.2.1 Crie um programa que adicione 5 nomes digitados pelo usuário em uma lista vazia e,
# após isso, exclua um nome da lista, também fornecido pelo usuário.

L12a = []
L12a.append(input("Nome 1:"))
L12a.append(input("Nome 2:"))
L12a.append(input("Nome 3:"))
L12a.append(input("Nome 4:"))
L12a.append(input("Nome 5:"))
print(f'Here is your list: {L12a}')
L12a.remove(input("Which name do you want to erase?"))
print(f'Sua lista: {L12a}')
# Out:
# Nome 1: A
# Nome 2: B
# Nome 3: C
# Nome 4: D
# Nome 5: E
# Here is your list: ['A', 'B', 'C', 'D', 'E']
# Which name do you want to erase? D
# Sua lista: ['A', 'B', 'C', 'E']

# %%
# 1.2.1 (enhanced)
lv = []
for i in range(5): # looping
    nm = input(f"Nome {i+1}: ") ## {i+1} incrementa a posicao
    lv.append(nm)
print(f'Lista: {lv}')
# Out:
# Nome 1:  um
# Nome 2:  dois
# Nome 3:  tres
# Nome 4:  quatro
# Nome 5:  cinco
# Lista: ['um', 'dois', 'tres', 'quatro', 'cinco']

# %%
# 1.2.1 (enhanced)
lv = []
for i in range(5): # looping ..
    nm = input(f"Nome {i+1}: ") ## {i+1} increment position
    lv.append(nm)
print(f'Lista: {lv}')

exclude = input("Exclua um nome: ")
if exclude in lv:
    lv.remove(exclude)
    print(f"Nova lista: {lv}")
else:
        print(f"Palavra não esta na lista.")
# Out:
# Nome 1:  Ra
# Nome 2:  Re
# Nome 3:  Ri
# Nome 4:  Ro
# Nome 5:  Ru
# Lista: ['Ra', 'Re', 'Ri', 'Ro', 'Ru']
# Exclua um nome:  Ri
# Nova lista: ['Ra', 'Re', 'Ro', 'Ru']

# %%
# 1.2.1 (enhanced)
lv = []
for i in range(5): # looping ..
    nm = input(f"Nome {i+1}: ") ## {i+1}. i comeca no 0 (zero). i esta incrementando.
    lv.append(nm)
print(f'Lista: {lv}')

exclude = input("Exclua um nome: ")
if exclude in lv:
    lv.remove(exclude)
    print(f"Nova lista: {lv}")
else:
        print(f"Palavra não esta na lista.")

# %%
# 1.3 Crie uma lista com 5 números inteiros fornecidos pelo usuário.
lista_int = [input(f"inteiro: "), input(f"inteiro: "), input(f"inteiro: "), input(f"inteiro: "), input(f"inteiro: "), ]
print(lista_int)
print(type(lista_int[1]))
print(type(lista_int[3]))
# Out:
# inteiro: 15
# inteiro: R
# inteiro: 15
# inteiro: 15
# inteiro: 15
# ['15', 'R', '15', '15', '15']
# <class 'str'>
# <class 'str'>

# %%
# 1.3 Crie uma lista com 5 números inteiros fornecidos pelo usuário.
lista_int = [int(input(f"inteiro: ")), int(input(f"inteiro: ")), int(input(f"inteiro: ")), int(input(f"inteiro: ")), int(input(f"inteiro: "))]
print(lista_int)
print(type(lista_int[1]))
print(type(lista_int[3]))
# Out:
# inteiro: 15
# inteiro: 15
# inteiro: 15
# inteiro: 15
# inteiro: 15
# [15, 15, 15, 15, 15]
# <class 'int'>
# <class 'int'>

# %%
print(lista_int)
# Out:
# [15, 15, 15, 15, 15]

# %%
# 1.3.1 Crie uma nova lista com o dobro dos valores da lista anterior.
print(lista_int)
c = len(lista_int) # qtd de posicoes na lista
double_list = lista_int.copy()
for i in range(c):
  double_list[i] = lista_int[i]*2

print(double_list)
# Out:
# [15, 15, 15, 15, 15]
# [30, 30, 30, 30, 30]

# %%
# 1.3.1 (melhorado)
print(lista_int)
double_list = lista_int.copy()
for i in range(len(lista_int)):
  double_list[i] = lista_int[i]*2

print(double_list)
# Out:
# [15, 15, 15, 15, 15]
# [30, 30, 30, 30, 30]

# %%
# 3.  Faça um programa que permita o usuário, a partir do nome do item, receber o preço correspondente.
produtos = ['Arroz', 'Feijao', 'Leite', 'Pao Frances', 'Ovos', 'Acucar', 'Farinha De Trigo', 'Oleo De Soja', 'Tomate', 'Banana', 'Maca', 'Cafe Em Po', 'Carne Bovina', 'Peito De Frango', 'Batata', 'Cebola', 'Alface', 'Agua', 'Queijo Mussarela', 'Arroz Integral']
precos = [8.0, 12.5, 5.8, 10.0, 14.4, 4.5, 4.0, 7.0, 10.24, 9.72, 14.6, 18.0, 54.0, 25.0, 7.17, 6.32, 5.8, 4.0, 62.0, 10.0]

prod = input("Produto: ")
print(f"O produto \"{produtos[produtos.index(prod)]}\", custa {precos[produtos.index(prod)]}")
# Out:
# Produto: Leite
# O produto "Leite", custa 5.8

# %%
# 3.  (melhorado)
# Reaproveitando a declaracao das listas produtos e precos.
prod = input("Produto: ")
if prod in produtos:
  print(f"O produto \"{produtos[produtos.index(prod)]}\", custa {precos[produtos.index(prod)]:.2f}")
else:
  print("Não encontrado.")
# Out:
# Produto: Ovos
# O produto "Ovos", custa 14.40

# %%
lista = ["a", "b"]
lista.append("c")
lista.append("d")
print(lista)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# **4.** Resolva:
# 1. A partir da lista dada, calcule a soma, média, maior e menor número.
# Use somente conceitos de List Slicing (posições de lista) e as funções len e print.

# Salve estes dados numa nova de resultados e crie uma lista sequencial com os números dados
# [47, 12, 89, 3, 56]

lista4 = [47, 12, 89, 3, 56]
nova_lista4 = []
# sum
soma4 = sum(lista4)
nova_lista4.append(soma4)
print(f"Soma: {soma4}")
# average
media4 = sum(lista4)/len(lista4)
nova_lista4.append(media4)
print(f"Media: {media4}")
# max
lista4.sort(reverse=True)
nova_lista4.append(lista4[0])
print(f"Max: {lista4[0]}")
#min
lista4.sort(reverse=False)
nova_lista4.append(lista4[0])
print(f"Min: {lista4[0]}")

print(nova_lista4)
# Out:
# Soma: 207
# Media: 41.4
# Max: 89
# Min: 3
# [207, 41.4, 89, 3]

# %%
lista4 = [47, 12, 89, 3, 56]
nova_lista4 = lista4.sort(reverse=True)
#print(nova_lista4)

# %%
# **4.** (clean...)

lista4 = [47, 12, 89, 3, 56]
nova_lista4 = []

soma4 = sum(lista4)
nova_lista4.append(soma4)

media4 = sum(lista4)/len(lista4)
nova_lista4.append(media4)

lista4.sort(reverse=True)
nova_lista4.append(lista4[0])

lista4.sort(reverse=False)
nova_lista4.append(lista4[0])

print(nova_lista4)
# Out:
# [207, 41.4, 89, 3]

# %%
## Queria tentar resolver sem usar a funcao max() e salvar o valor max em uma variavel ou algo parecido ...

lista_m = [55, 2, 548, 9, 1]
lista_m.sort(reverse=True)
# max[0] = lista_m[0]
max_num4 = []
max_num4.append(lista_m[0])
print(lista_m)
print(max_num4[0])
## funciona mas da trabalho e é meio confuso ...
# Out:
# [548, 55, 9, 2, 1]
# 548

# %%
#4.a
lista4 = [47, 12, 89, 3, 56]
nova_lista4 = []

soma4 = sum(lista4)
nova_lista4.append(soma4)

media4 = sum(lista4)/len(lista4)
nova_lista4.append(media4)

lista4.sort(reverse=True)
nova_lista4.append(lista4[0])

lista4.sort(reverse=False)
nova_lista4.append(lista4[0])

print(nova_lista4)

# 4.b. Crie uma lista chamada Operacoes com as Strings referentes aos nomes das operações calculadas anteriormente e imprima, a seguir:
# O cálculo de <Soma> Resultou em <400>, substituindo o <soma> por um elemento da lista de operações, e o <400> pelo resultado daquela operação.



# Achei o enunciado estranho, é basicamente o que já fizemos no ex 3 ... enfim.
operacoes = ["Soma", "Media", "Maior", "Menor"]

for i in range(len(operacoes)): # "usando" as string declaradas dentro da lista operacoes como indices para navegacao do looping
  print(f"O calculo de {operacoes[i]} resultou em US$ {nova_lista4[i]:.2f}")

# Acho que peguei a ideia
# É um jeito diferente de usar as coisas, acho que era esse o objetivo desse exercicio.
# Out:
# [207, 41.4, 89, 3]
# O calculo de Soma resultou em US$ 207.00
# O calculo de Media resultou em US$ 41.40
# O calculo de Maior resultou em US$ 89.00
# O calculo de Menor resultou em US$ 3.00

# %%
produtos = [' beb46275','TFA23962','TFA64715','TFA69555','TFA56743', 'BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623', 'BSA62419','BEB73344',
'TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417',
'TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

precos = [1258.69, 917.65, 1050.26, 414.36, 904.9, 1077.77, 640.14, 379.92, 1201.62, 1206.15, 1256.34, 729.27, 1252.72, 432.89, 457.95, 1191.3, 421.77, 1165.32, 1040.62,
781.12, 1059.19, 1232.68, 1112.44, 1265.35, 575.2, 1150.78, 544.38, 949.14, 1043.73, 758.28, 398.22, 662.56, 723.15, 468.72, 366.52, 513.45, 703.74, 421.34, 961.38]

# **5.** **Usando for** Uma empresa lhe pediu para criar um programa que separasse bebidas alcóolicas e suplementos de uma lista qualquer
# que lhe fosse provida para pagamento separado.
# A tarefa exige que, dada uma lista qualquer,  seu programa separe os dois itens (uma lista de bebidas alcóolicas e uma lista de suplementos),
# armazenando:
# uma nova lista com todas as bebidas, e outra com seus respectivos preços
# uma nova lista com todos os suplementos, e outra com seus respectivos preços
# o valor total para pagamento de cada uma das listas, separados.

# As bebidas alcóolicas começam com o código BEB, e os suplementos com o código TFA.

# %%
# 5. building the logic ....

prod_alc = []
price_alc = []
prod_sup = []
price_sup = []

len(produtos)

for i in range(len(produtos)):
  if "BEB" in produtos[i]:
    print(f"{produtos[i]} eh alcoolico")
  else:
    print(f"{produtos[i]} nao eh alcoolico")
# Out:
#  beb46275 nao eh alcoolico
# TFA23962 nao eh alcoolico
# TFA64715 nao eh alcoolico
# TFA69555 nao eh alcoolico
# TFA56743 nao eh alcoolico
# BSA45510 nao eh alcoolico
# TFA44968 nao eh alcoolico
# CAR75448 nao eh alcoolico
# CAR23596 nao eh alcoolico
# CAR13490 nao eh alcoolico
# BEB21365 eh alcoolico
# BEB31623 eh alcoolico
# BSA62419 nao eh alcoolico
# BEB73344 eh alcoolico
# TFA20079 nao eh alcoolico
# BEB80694 eh alcoolico
# BSA11769 nao eh alcoolico
# BEB19495 eh alcoolico
# TFA14792 nao eh alcoolico
# TFA78043 nao eh alcoolico
# BSA33484 nao eh alcoolico
# BEB97471 eh alcoolico
# BEB62362 eh alcoolico
# TFA27311 nao eh alcoolico
# TFA17715 nao eh alcoolico
# BEB85146 eh alcoolico
# BEB48898 eh alcoolico
# BEB79496 eh alcoolico
# CAR38417 nao eh alcoolico
# TFA19947 nao eh alcoolico
# TFA58799 nao eh alcoolico
# CAR94811 nao eh alcoolico
# BSA59251 nao eh alcoolico
# BEB15385 eh alcoolico
# BEB24213 eh alcoolico
# BEB56262 eh alcoolico
# BSA96915 nao eh alcoolico
# ...

# %% [markdown]
# Ex.10: Desafio, pesquise sobre a função for. Uma empresa lhe pediu para criar um programa que separasse bebidas alcóolicas e suplementos de uma lista qualquer que lhe fosse provida para pagamento separado. A tarefa exige que, dada uma lista qualquer, seu programa separe os dois itens (uma lista de bebidas alcóolicas e uma lista de suplementos), armazenando:
# - uma nova lista com todas as bebidas, e outra com seus respectivos preços.
# - uma nova lista com todos os suplementos, e outra com seus respectivos preços
# - valor total para pagamento de cada uma das listas, separados.
# As bebidas alcóolicas começam com o código BEB, e os suplementos com o código TFA.

# %%
# 5. ## list names: produtos & precos

prod_alc = []
price_alc = []
prod_sup = []
price_sup = []

for i in range(len(produtos)):
  if "BEB" in produtos[i]:
    prod_alc.append(produtos[i])
    price_alc.append(precos[i])
  else:
    prod_sup.append(produtos[i])
    price_sup.append(precos[i])

print(f'Produtos \"BEB\" alcoolicos: {prod_alc}')
print(f'Precos \"BEB\" alcoolicos: {price_alc}\n')
print(f'Produtos \"Sup\": {prod_sup}')
print(f'Precos \"Sup\": {price_sup}\n')
# Out:
# Produtos "BEB" alcoolicos: ['BEB21365', 'BEB31623', 'BEB73344', 'BEB80694', 'BEB19495', 'BEB97471', 'BEB62362', 'BEB85146', 'BEB48898', 'BEB79496', 'BEB15385', 'BEB24213', 'BEB56262', 'BEB75073']
# Precos "BEB" alcoolicos: [1256.34, 729.27, 432.89, 1191.3, 1165.32, 1232.68, 1112.44, 1150.78, 544.38, 949.14, 468.72, 366.52, 513.45, 961.38]
#
# Produtos "Sup": [' beb46275', 'TFA23962', 'TFA64715', 'TFA69555', 'TFA56743', 'BSA45510', 'TFA44968', 'CAR75448', 'CAR23596', 'CAR13490', 'BSA62419', 'TFA20079', 'BSA11769', 'TFA14792', 'TFA78043', 'BSA33484', 'TFA27311', 'TFA17715', 'CAR38417', 'TFA19947', 'TFA58799', 'CAR94811', 'BSA59251', 'BSA96915', 'CAR53454']
# Precos "Sup": [1258.69, 917.65, 1050.26, 414.36, 904.9, 1077.77, 640.14, 379.92, 1201.62, 1206.15, 1252.72, 457.95, 421.77, 1040.62, 781.12, 1059.19, 1265.35, 575.2, 1043.73, 758.28, 398.22, 662.56, 723.15, 703.74, 421.34]

# %%
## EXTRA
## Caso simplesmente deseje economizar linhas de código:

l = []
l.append(1),l.append(2),l.append(3)
l.extend([4,5,6,7])
# Caso queira adicionar várias strings:
l.extend(input().split())
# Caso queira adicionar algo que não string (exemplo int):
l.extend(list(map(int, input().split())))

print(l)
# Out:
# R
# 50
# [1, 2, 3, 4, 5, 6, 7, 'R', 50]
