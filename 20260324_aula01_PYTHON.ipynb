# %%
## Funções Básicas
# Out:
# Hello word!

# %%
## sintaxe da função: Nome_da_função()
print("Hello word!")
# Out:
# Hello word!

# %%
print(1+1)
a=5+2
print(a)
print("Hello hello hello")
nome = "Renan"
print(nome)
# Out:
# 2
# 7
# Hello hello hello
# Renan

# %%
idade = 999
nome = 'Rennann'
print(nome)
print(idade)

print(idade)
print(nome)
# Out:
# Rennann
# 999
# 999
# Rennann

# %%
nome = "Renan"
print(type(nome))
idade = 31
print(type(idade))
peso = 65.5
print(type(peso))
resultado = 10 > 3
print(type(resultado))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
NAME = input("Qual seu nome? ")
print(NAME)
# Out:
# Qual seu nome?  R
# R

# %%
idade = input("Qual sua idade?")
idade = int(idade)
print(idade*2)
# Out:
# Qual sua idade? 50
# 100

# %%
idade = input("Qual sua idade?")
print(int(idade)*2)
# Out:
# Qual sua idade? 5
# 10

# %%
name = "Charles"
age = 65
print("Seu nome é {}, você tem {} anos de idade.".format(name,age))
# Out:
# Seu nome é Charles, você tem 65 anos de idade.

# %%
print(f'Seu nome é {nome}, você tem {idade} anos de idade.')
# Out:
# Seu nome é Rennann, você tem 50 anos de idade.

# %%
## Lista de exercicios
## 1. Crie um programa que pergunte ao usuário seu nome e imprima a mensagem “bom dia {nome}” do usuário.
## 2. Crie um programa que pergunte a idade de um usuário. Informe quantos anos faltam para ele ter 100 anos.
## 3. Crie um programa em python que leia dois nomes, e salve em duas variáveis distintas. 
## Após, o programa deve imprimir a mensagem <{nome1} e {nome2} comparecerão na festa.
## 4. Numa situação real do dia a dia de Adriana, ela precisa fazer o orçamento de 5 itens para seus clientes, 
# e mostrar uma mensagem com o total. Faça um programa que resolva esta situação simples de soma pra ela, 
# imprimindo a mensagem, ao final: <O total do orçamento foi R${total}>
## 5. - A partir do código abaixo, informe o tipo de cada uma das variáveis:
    # - Dados
    #     a = 12
    #     b = 1.5
    #     c = '10'
    #     d = 'leonardo'
    #     e = int('123')
    #     f = float(1)
    #     g = float('10.5')
    #     h = a
    #     j = str(float(int(input('informe seu salário (com centavos, separados por ponto)'))))
## 6. Crie 10 variáveis. Utilize um print, somente, para informar cada uma dessas variáveis. 
# Dica: Para pular linhas dentro de um print, basta utilizar um \n. 
# Exemplo: print(’bom dia\nBoa tarde\nBoa noite’)
## 7. Crie um script em python que pergunte o nome, a idade, o salário e as despesas mensais de um indivíduo 
# utilizando a função input(). Crie, então, uma resposta que diga:
# "O <nome> recebe <salario> tendo <idade> anos e tem <restante> disponível ao fim do mês"


NAME = input("Qual seu nome? ")
print(NAME)
