# %%
# Funcoes - Teoria

# %%
def saudacao(nome):
    print(f"Olá, {nome}!")

saudacao("Maria")
# Out:
# Olá, Maria!

# %%
def saudacao(nome):
    print(f"Olá, {nome}!")

minha_funcao = saudacao
minha_funcao("João")
# Out:
# Olá, João!

# %%
def aplicar_funcao(funcao, valor):
    resultado = funcao(valor)
    return resultado

def dobro(x):
    return x * 2

resultado = aplicar_funcao(dobro, 3)  # Passando a função dobro como argumento
print("seu resultado", resultado)
# Out:
# seu resultado 6

# %%
def fat_n(f):
  if f == 1:
    return f
  else:
    return f * fat_n(f-1)

f = int(input())
print(fat_n(f))
# Out:
# 3
# 6

# %%
def fatorial(n):
    if n == 0:
        return 1
    else:
        return n * fatorial(n-1)

print(fatorial(5))
# Out:
# 120

# %% [markdown]
# Teoria

# %%
def teste(y):
  return f'... {y}'

y = input("Insira algo: ")
mensagem = teste(y)
print(mensagem)
# Out:
# Insira algo: R
# ... R

# %%
# EXERCÍCIOS

# %%
# 1. Crie uma função chamada aniversario. Ela deve perguntar qual o nome da pessoa e imprimir a mensagem “Feliz anivervario, <nome>!”

# sintaxe
# def nome_da_funcao():
#   # codigo #

# nome_da_funcao() # chamando a funcao

def aniversario():
  n = input("Nome do aniversáriante: ")
  print(f'Feliz aniversário, {n}')

aniversario()
# Out:
# Nome do aniversáriante: Renan
# Feliz aniversário, Renan

# %%
# 2 Mesmo que o ex1., porém imprima a frase 3 vezes.
def bom_dia():
  for i in range(3): # modifiquei o enunciado da frase
    n = input("Qual seu nome ").title()
    print(f'Bom dia, {n}!')

bom_dia()
# Out:
# Qual seu nome R
# Bom dia, R!
# Qual seu nome B
# Bom dia, B!
# Qual seu nome C
# Bom dia, C!

# %%
# 2 Mesmo que o ex1., porém imprima a frase 3 vezes.
def bom_dia(n):
    return f'Bom dia, {n}!'

for i in range(3): # modifiquei o enunciado da frase
  mensagem = bom_dia(input("Qual seu nome ").title())
  print(mensagem)
# Out:
# Qual seu nome Renan
# Bom dia, Renan!
# Qual seu nome Julia
# Bom dia, Julia!
# Qual seu nome Fabi
# Bom dia, Fabi!

# %%
# 2 (melhorado) Esse está ok.
def bom_dia():
    n = input("Qual seu nome ").title()
    print(f'Bom dia, {n}!')

bom_dia()
bom_dia()
bom_dia()
# Out:
# Qual seu nome Renan
# Bom dia, Renan!
# Qual seu nome Maria
# Bom dia, Maria!
# Qual seu nome Joana
# Bom dia, Joana!

# %%
# 2 (DEU CERTO, RESULTADO NAO É O ESPERADO)
def bom_dia():
    n = input("Qual seu nome ").title()
    return f'Bom dia, {n}!'

bom_dia()
bom_dia()
bom_dia() # Não fazer isso,  só o ultimo return funciona.
# Out:
# Qual seu nome R
# Qual seu nome F
# Qual seu nome T
# 'Bom dia, T!'

# %%
# 3- Utilizando como base a função do Ex.1, faça com
# que, ao invés de printar, ele retorne a mensagem.
# Salve essa mensagem em uma variável do seu programa
# e deixe todas as letras em maiúsculo antes de imprimir

def aniversario():
  n = input("Nome do aniversáriante: ")
  n = f"Feliz aniversário, {n}"
  return n


x = aniversario()
print(x.upper())
# Out:
# Nome do aniversáriante: luana
# FELIZ ANIVERSÁRIO, LUANA

# %%
# 3- Utilizando como base a função do Ex.1, faça com
# que, ao invés de printar, ele retorne a mensagem.
# Salve essa mensagem em uma variável do seu programa
# e deixe todas as letras em maiúsculo antes de imprimir

# Melhorada

def aniversario(s):
  return f"Feliz aniversário, {s}"

# x = aniversario(input("Nome do aniversáriante: "))
# print(x.upper())
print(aniversario(input("Nome do aniversáriante: ")).upper())
# Out:
# Nome do aniversáriante: Lilian
# FELIZ ANIVERSÁRIO, LILIAN

# %%
# 4. utilizando while True, faça um menu de funções:
# <1- Soma>,<2-Subtração>,<3-Multiplicação>,<4-Divisão>,
# <5-Sair>; O usuário deve decidir o que fazer com base
# neste menu.

def calculadora_simples():
  while True:
    print("calculadora simples.\n1-Soma\n2-Subtração\n3-Multiplicação\n4-Divisão\n5-Sair")
    x = int(input("Operação "))
    match x:
      case 1: # soma
        n1 = int(input("n1: "))
        n2 = int(input("n2: "))
        r = n1 + n2
      case 2: # subtração
        n1 = int(input("n1: "))
        n2 = int(input("n2: "))
        r = n1 - n2
      case 3: # multiplicacao
        n1 = int(input("n1: "))
        n2 = int(input("n2: "))
        r = n1 * n2
      case 4: # Divisao
        n1 = int(input("n1: "))
        n2 = int(input("n2: "))
        r = n1 / n2
      case 5:
        break
      case _:
        print("Inválido.")
    return r

print("Resultado: ", calculadora_simples())
# Out:
# calculadora simples.
# 1-Soma
# 2-Subtração
# 3-Multiplicação
# 4-Divisão
# 5-Sair
# Operação 1
# n1: 2
# n2: 2
# Resultado:  4

# %%
# 4. utilizando while True, faça um menu de funções:
# <1- Soma>,<2-Subtração>,<3-Multiplicação>,<4-Divisão>,
# <5-Sair>; O usuário deve decidir o que fazer com base
# neste menu.

# melhorado

def calculadora_simples():
  while True:
    print("calculadora simples.\n1-Soma\n2-Subtração\n3-Multiplicação\n4-Divisão\n5-Sair")
    x = int(input("Operação "))
    n1 = float(input("n1: "))
    n2 = float(input("n2: "))
    match x:
      case 1: # soma
        r = n1 + n2
      case 2: # subtração
        r = n1 - n2
      case 3: # multiplicacao
        r = n1 * n2
      case 4: # Divisao
        r = n1 / n2
      case 5:
        break
      case _:
        print("Inválido.")
    return r

print("Resultado: ", calculadora_simples())
# Out:
# calculadora simples.
# 1-Soma
# 2-Subtração
# 3-Multiplicação
# 4-Divisão
# 5-Sair
# Operação 2
# n1: 3
# n2: 5
# Resultado:  -2.0

# %%
# 4. utilizando while True, faça um menu de funções:
# <1- Soma>,<2-Subtração>,<3-Multiplicação>,<4-Divisão>,
# <5-Sair>; O usuário deve decidir o que fazer com base
# neste menu.

# melhorado

def calculadora_simples(x, n1, n2):
  while True:
    match x:
      case 1: # soma
        r = n1 + n2
      case 2: # subtração
        r = n1 - n2
      case 3: # multiplicacao
        r = n1 * n2
      case 4: # Divisao
        r = n1 / n2
      case 5:
        break
      case _:
        print("Inválido.")
    return r


print("calculadora simples.\n1-Soma\n2-Subtração\n3-Multiplicação\n4-Divisão\n5-Sair")
# x = int(input("Operação "))
# n1 = float(input("n1: "))
# n2 = float(input("n2: "))
# resultado = calculadora_simples(x, n1, n2) # Funciona bem
a = int(input("Operação "))
b = float(input("n1: "))
c = float(input("n2: "))
resultado = calculadora_simples(a, b, c) # testando se o nome importa, funciona bem também.
print(f"Resultado: {resultado}")
# Out:
# calculadora simples.
# 1-Soma
# 2-Subtração
# 3-Multiplicação
# 4-Divisão
# 5-Sair
# Operação 1
# n1: 5
# n2: 3
# Resultado: 8.0

# %%
# Definindo

def somar(a, b): return a + b
def subtrair(a, b): return a - b
def multiplicar(a, b): return a * b
def dividir(a, b): return a / b if b != 0 else "Erro: Divisão por zero"

while True:
    print("\n--- MENU CALCULADORA ---")
    opcao = input("Escolha (1-5): ")

    if opcao == '5':
        print("Saindo...")
        break # Desliga o loop

    n1 = float(input("Primeiro valor: "))
    n2 = float(input("Segundo valor: "))

    match opcao:
        case '1': print("Resultado:", somar(n1, n2))
        case '2': print("Resultado:", subtrair(n1, n2))
        case '3': print("Resultado:", multiplicar(n1, n2))
        case '4': print("Resultado:", dividir(n1, n2))
        case _: print("Opção inválida!")

# %%
# 5. Exercicio de refatoração foi refeito nas proprias exercícios anteriores

# %% [markdown]
# Refatoração (Funções Puras): Recrie, a partir do ex 2, as funções anteriores removendo todos os input() e print() de dentro delas. Use parâmetros para receber os dados.

# %%
# 6 Crie uma variável <saldo>. Crie as seguintes funções bancárias: Consultar saldo, sacar, depositar. Desafio: Crie um sistema de contas (utilizando dicionários ou listas), com as opções: Transferência entre contas e limita de crédito pessoal, além de todas as opções acima para cada conta origem e destino.

# %% [markdown]
# 6. Crie uma variável {saldo}. Crie as seguintes funções bancárias: Consultar saldo, sacar, depositar. Desafio: Crie um sistema de contas (utilizando dicionários ou listas), com as opções: Transferência entre contas e limite de crédito pessoal, além de todas as opções acima para cada conta origem e destino.

# %%
saldo1 = 300 # saldo corrente.
saldo2 = 5000.00 # saldo porquinho.
credito = 0

# def consultar_saldo(): print(f'Saldo atual: US${saldo:.2f}')
# def consultar_saldo(): return f'Saldo atual: US${saldo1:.2f}'
def consultar_saldo(x1,x2): return saldo1,saldo2

def realizar_saque(saldo1):
  num = input("Saque [Digite números inteiros.]: ") # string
  # if num.isnumeric(): # Verifica se a string é um numérica (se é um numero)
  # No mundo real, em ATMs, o saque é feito em numero inteiro. Entao vou aceitar a solucao e seguir por essa logica.
  if num.isnumeric(): # Retirar isso na refatoração, é meio inutil e me da trabalho extra...
    num = int(num) # mudando o tipo para float.
    if num > saldo1:
      return "Saldo Conta Corrente insuficiente"
    else:
      saldo1 -= num # subtracao
  else:
    return "Erro no saque."
  return saldo1

def realizar_deposito(saldo1):
  num = int(input("Deposito: "))
  saldo1 += num # soma
  return saldo1

def realizar_transferencia(saldo1,saldo2):
  num = int(input("Transferir: "))
  t = int(input("op 1 - Conta Corrente para Conta Poupanca.\nop 2 - Conta Poupança para Conta Corrente.\n"))
  match t:
    case 1:
      if num > saldo1:
        print("Saldo Corrente Insuficiente.")#; break
      else:
        saldo1 -= num # subtracao
        saldo2 += num # soma
    case 2:
      if num > saldo2:
        print("Saldo Poupanca Insuficiente.")#; break
      else:
        saldo1 += num # soma
        saldo2 -= num # subtracao
  return saldo1,saldo2

while True:
  print("ATM $ENAI\n1- Consultar Saldo\n2- Sacar Conta Corrente\n3- Depositar Conta Corrente\n4- Transferencia entre contas\n5- Limite de Credito Pessoal\n6- Sair\n")
  op = int(input("Menu de operações: "))
  match op:
    case 1: # conta corrente
      # r = consultar_saldo()
      # print(f'{r}\n')
      r1,r2 = consultar_saldo(saldo1,saldo2)
      print(f'Saldo Conta Corrente: US${saldo1:.2f}')
      print(f'Saldo Conta Poupança: US${saldo2:.2f}\n')
      pass # Added pass to resolve IndentationError
    case 2:
      # print(realizar_saque(saldo1)) # Lembre de salvar o valor retornado e nao só usar no print
      saldo1 = realizar_saque(saldo1)
      print(f'Saldo atual: US${saldo1:.2f}\n')
    case 3:
      saldo1 = realizar_deposito(saldo1) # Lembre de salvar o valor retornado e nao só usar no print
      print(f'Saldo atual: US${saldo1:.2f}\n')
    case 4:
      print(f'Saldo conta principal: US${saldo1:.2f}')
      print(f'Saldo conta poupanca: US${saldo2:.2f}\n')
      saldo1, saldo2 = realizar_transferencia(saldo1,saldo2)
      print(f'Saldo conta principal: US${saldo1:.2f}')
      print(f'Saldo conta poupanca: US${saldo2:.2f}\n')
    case 5:
      if credito == 0:
        credito = float(input("Informe Renda Liquida Mensal: "))
        print(f"Voce tem um crédito pré-aprovado de US${6*credito:.2f}\nEntre em contato com a agencia para liberação.\n")
    case 6:
      print("Exit."); break
    case _:
      print("Opção inválida\n"); break
# Out:
# ATM $ENAI
# 1- Consultar Saldo
# 2- Sacar Conta Corrente
# 3- Depositar Conta Corrente
# 4- Transferencia entre contas
# 5- Limite de Credito Pessoal
# 6- Sair
#
# Menu de operações: 1
# Saldo Conta Corrente: US$300.00
# Saldo Conta Poupança: US$5000.00
#
# ATM $ENAI
# 1- Consultar Saldo
# 2- Sacar Conta Corrente
# 3- Depositar Conta Corrente
# 4- Transferencia entre contas
# 5- Limite de Credito Pessoal
# 6- Sair
#
# Menu de operações: 4
# Saldo conta principal: US$300.00
# Saldo conta poupanca: US$5000.00
#
# Transferir: 500
# op 1 - Conta Corrente para Conta Poupanca.
# op 2 - Conta Poupança para Conta Corrente.
# 2
# Saldo conta principal: US$800.00
# Saldo conta poupanca: US$4500.00
#
# ATM $ENAI
# 1- Consultar Saldo
# 2- Sacar Conta Corrente
# 3- Depositar Conta Corrente
# 4- Transferencia entre contas
# 5- Limite de Credito Pessoal
# 6- Sair
#
# Menu de operações: 1
# Saldo Conta Corrente: US$800.00
# Saldo Conta Poupança: US$4500.00
#
# ATM $ENAI
# 1- Consultar Saldo
# ...

# %%
## Continuar trabalhando nessa solução

s = 1000

num = input("Saque [Digite números inteiros.]: ") # string
# if num.isnumeric(): # usando a funcao para verificar se a string é um numérica (se é um numero)
# No mundo real, em ATMs, o saque é feito em numero inteiro. Entao vou aceitar a solucao e seguir por essa logica.
if num.isalnum():
  # num = float(num) # mudando o tipo para float. Implementação futura ...
  if num > s:
    print("Saldo insuficiente")
  else:
    s -= num
else:
  print("Erro.")

return s
print(s)
# Out:
# Saque: 15.5
# Erro.
# 1000

# %%
# REFATORANDO EXERCICIO 6

saldo1 = 300 # saldo corrente.
saldo2 = 5000.00 # saldo poupança.
credito = 0

# Operacoes Bancarias Básicas
def consultar_saldo(x1,x2):
  return saldo1,saldo2

def realizar_saque(saldo1,num):
  if num > saldo1:
    print("Saldo Conta Corrente insuficiente")
    return saldo1
  else:
    return saldo1 - num

def realizar_deposito(saldo1,num):
  return saldo1 + num

def realizar_transferencia(saldo1,saldo2,t,num):
  match t:
    case 1:
      if num > saldo1:
        print("Saldo Corrente Insuficiente.")
      else:
        saldo1 -= num # subtracao
        saldo2 += num # soma
    case 2:
      if num > saldo2:
        print("Saldo Poupanca Insuficiente.")
      else:
        saldo1 += num # soma
        saldo2 -= num # subtracao
  return saldo1,saldo2

while True:
  print("ATM $ENAI\n1- Consultar Saldo\n2- Sacar Conta Corrente\n3- Depositar Conta Corrente\n4- Transferencia entre contas\n5- Limite de Credito Pessoal\n6- Sair\n")
  op = int(input("Menu de operações: "))
  match op:
    case 1:
      # r1,r2 = consultar_saldo(saldo1,saldo2) # pensei que ia dar problema
      # Que passar os valores das var saldo para r1 e r2 não iria atualizar os valores das var saldo
      # esqueci que nao é assim que funciona. Eu alterei o valor que estava sendo apontado pelo endereco de memoria.
      # deu certo, mas ainda nao tenho certeza se eu acessei o endereco de memoria
      # DEPOIS DE PENSAR UM POUCO, percebi que posso ter cometido um pequeno erro
      # Só nao deu errado pq eu só estou consultando o saldo
      # eu ainda nao tenho certeza se o que eu passei pra eles (r1 r2) foi o endereço de memoria dos saldos ou uma cópia dos valores.
      r1,r2 = consultar_saldo(saldo1,saldo2)
      print(f'Saldo Conta Corrente: US${r1:.2f}')
      print(f'Saldo Conta Poupança: US${r2:.2f}\n')
    case 2:
      num = int(input("Saque [Digite números inteiros.]: "))
      saldo1 = realizar_saque(saldo1,num)
      print(f'Conta Corrente: US${saldo1:.2f}\n')
    case 3:
      num = int(input("Deposito [Digite números inteiros.]: "))
      saldo1 = realizar_deposito(saldo1,num)
      print(f'Conta Corrente: US${saldo1:.2f}\n')
    case 4:
      print(f'Saldo conta principal: US${saldo1:.2f}')
      print(f'Saldo conta poupanca: US${saldo2:.2f}')
      t = int(input("op 1 - Conta Corrente para Conta Poupanca.\nop 2 - Conta Poupança para Conta Corrente.\n"))
      num = int(input("Transferir: "))
      saldo1, saldo2 = realizar_transferencia(saldo1,saldo2,t,num)
      print(f'Saldo conta principal: US${saldo1:.2f}')
      print(f'Saldo conta poupanca: US${saldo2:.2f}\n')
    case 5:
      if credito == 0:
        credito = float(input("Informe Renda Liquida Mensal: "))
        print(f"Voce tem um crédito pré-aprovado de US${6*credito:.2f}\nEntre em contato com a agencia para liberação.\n")
    case 6:
      print("Exit."); break
    case _:
      print("Opção inválida\n"); break
# Out:
# ATM $ENAI
# 1- Consultar Saldo
# 2- Sacar Conta Corrente
# 3- Depositar Conta Corrente
# 4- Transferencia entre contas
# 5- Limite de Credito Pessoal
# 6- Sair
#
# Menu de operações: 4
# Saldo conta principal: US$300.00
# Saldo conta poupanca: US$5000.00
# op 1 - Conta Corrente para Conta Poupanca.
# op 2 - Conta Poupança para Conta Corrente.
# 2
# Transferir: 500
# Saldo conta principal: US$800.00
# Saldo conta poupanca: US$4500.00
#
# ATM $ENAI
# 1- Consultar Saldo
# 2- Sacar Conta Corrente
# 3- Depositar Conta Corrente
# 4- Transferencia entre contas
# 5- Limite de Credito Pessoal
# 6- Sair
#
# Menu de operações: 6
# Exit.

# %% [markdown]
# Extras: ex7. Elabore uma função que pergunte a idade de uma pessoa e informe se ela pode ou não votar.

# %%
# def nome_da_funcao():
#   # codigo #

# nome_da_funcao() # chamando a func

def votar(y):
  if y >= 18:
    return 1
  else:
    return 0


x = int(input("Informe a idade em anos completos?\n"))
if votar(x) == 1:
  print("Você pode votar.")
else:
  print("Você não pode votar.")
# Out:
# Informe a idade em anos completos?
# 50
# Você pode votar.

# %%
def votar(y):
  if y >= 18:
    return "Você pode votar"
  else:
    return "Você não pode votar"

print(votar(int(input("Informe a idade em anos completos?\n"))))
# Out:
# Informe a idade em anos completos?
# 15
# Você não pode votar

# %% [markdown]
# Ex.8. Extras: Elabore uma função que pergunte dois números e informe qual deles é maior.

# %%
def qual_e(x1,x2):
  if x1 > x2:
    return x1
  if x1 < x2:
    return x2
  else:
    return -1

x1 = int(input("n1: "))
x2 = int(input("n2: "))
x3 = qual_e(x1,x2)

if x3 != -1:
  print(f'O maior é {x3}')
else:
  print("São iguais")
# Out:
# n1: 16
# n2: 16
# São iguais

# %% [markdown]
# Ex.9. Extras: Elabore uma função que pergunte qual o pet favorito dentre uma lista de 10 animais e informe se o pet que ela gosta é legal ou não.

# %%
def pet(x,y):
  if x == 0:
    print("Esse é meu garoto(a)!")
  else:
    print(f"mehhh, só existe uma escolha certa.\nE não é a sua, nota -5 pra vc e seu {animais[i]}.")

animais = [
    "Cachorro",
    "Gato",
    "Elefante",
    "Leão",
    "Tigre",
    "Girafa",
    "Zebra",
    "Panda",
    "Canguru",
    "Pinguim"
]

for i in range(len(animais)):
  print(f"{i}, {animais[i]}")
a = int(input("\nEscola um pet da lista e te direi se ele é legal ou não.\n"))
pet(a,animais[i])
# Out:
# 0, Cachorro
# 1, Gato
# 2, Elefante
# 3, Leão
# 4, Tigre
# 5, Girafa
# 6, Zebra
# 7, Panda
# 8, Canguru
# 9, Pinguim
#
# Escola um pet da lista e te direi se ele é legal ou não.
# 5
# mehhh, só existe uma escolha certa.
# E não é a sua, nota -5 pra vc e seu Pinguim.

# %% [markdown]
# Ex.10. Extras: Elabore uma função que pergunte o nome do aniversáriante e print bom dia.

# %%
def funcao10():
  nome = input("Qual o nome do aniversariante? ")
  print(f'Bom dia e Feliz Aniversário {nome}.')

funcao10()
# Out:
# Qual o nome do aniversariante? Renan
# BOM DIA E FELIZ ANIVERSÁRIO RENAN.

# %% [markdown]
# Ex.11. Extras: Utilizando essa mesma função, faça com que, ao invés de ela printar a mensagem, ela retorne a mensagem, salvando a váriavel de texto e deixando tudo em letras maiúsculas.

# %%
def funcao11():
  nome = input("Qual o nome do aniversariante? ")
  return f'Bom dia e Feliz Aniversário {nome}.'

f = funcao11().upper()
print(f)
# Out:
# Qual o nome do aniversariante? Renan
# BOM DIA E FELIZ ANIVERSÁRIO RENAN.

# %% [markdown]
# Ex.12. Extras: Desafio: (EM DESENVOLVIMENTO)
# 1) Crie uma funcao que repita 3 vezes a pergunta/resposta do parabéns.
# 2) Repita 3x a pergunta e printe só no final.
# 3) Repita 3x, salve em 3 variaveis diferentes e print tudo no programa principal.

# %%
# Crie uma funcao que repita 3 vezes a pergunta/resposta do parabéns.
def f12_1():
  for x in range(3):
    i = input("Qual seu nome? ")
    # return print(f'Olá {i}.')
    print(f'Olá {i}.')

f12_1()
# Out:
# Qual seu nome? R
# Olá R.
# Qual seu nome? F
# Olá F.
# Qual seu nome? G
# Olá G.

# %%
# Repita 3x a pergunta e printe só no final.
def f12_2():
    i = input("Qual seu nome? ")
    return f'Bom dia {i}.'

f12_2()
f12_2()
f12_2()
# Out:
# Qual seu nome? R
# Qual seu nome? F
# Qual seu nome? G
# 'Bom dia G.'

# %%
# Repita 3x, salve em 3 variaveis diferentes e print tudo no programa principal.
def f12_3(f):
    for i in range(3):
      f[i] = input("Qual seu nome? ")
    return print(f)

# f = [] # lista vazia da erro
f = [0,0,0]
f12_3(f)
# Out:
# Qual seu nome? R
# Qual seu nome? F
# Qual seu nome? G
# ['R', 'F', 'G']

# %% [markdown]
# Ex.13. Extras: Criar uma calculadora. Crie quatro funções, uma para cada operação básica! Essas funções devem receber dois números de ponto flutuante como argumentos, retornar um resultado e imprimir, por exemplo, “o resultado da sua multiplicação é: _”

# %%
def somar(a, b): return a + b
def subtrair(a, b): return a - b
def multiplicar(a, b): return a * b
def dividir(a, b): return a / b if b != 0 else "Erro: Divisão por zero"

print("Calculadora de Operações Básicas: ")
print("1- soma\n2- sub\n3- multi\n4- div\n5- sair")

while True:
    opcao = int(input("Escolha (1-5): "))
    if opcao == 5:  # melhor posicionado aqui
        print("Saindo...")
        break
    n1 = float(input("Primeiro valor: ")) # melhor posicionado aqui
    n2 = float(input("Segundo valor: "))
    match opcao:
      case 1: print("O resultado da sua soma é: ", somar(n1, n2))
      case 2: print("O resultado da sua subtracao é: ", subtrair(n1, n2))
      case 3: print("O resultado da sua multiplicacao é: ", multiplicar(n1, n2))
      case 4: print("O resultado da sua divisao é: ", dividir(n1, n2))
      case _:
        print("Opção inválida!")
# Out:
# Calculadora de Operações Básicas:
# 1- soma
# 2- sub
# 3- multi
# 4- div
# 5- sair
# Escolha (1-5): 5
# Saindo...

# %% [markdown]
# Ex.14. Extras: Crie uma função que, dada uma lista de produtos qualquer, ela cadastre em listas já existentes as bebidas alcoólicas e os suplementos (BEB e TFA). Parte 2: Passar como argumento também o código da categoria.

# %%
produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743',
'BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623',
'BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792',
'TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146',
'BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251',
'BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

precos = [1258.69, 917.65, 1050.26, 414.36, 904.9, 1077.77,
 640.14, 379.92, 1201.62, 1206.15, 1256.34, 729.27,
 1252.72, 432.89, 457.95, 1191.3, 421.77, 1165.32, 1040.62,
 781.12, 1059.19, 1232.68, 1112.44, 1265.35, 575.2, 1150.78,
 544.38, 949.14, 1043.73, 758.28, 398.22, 662.56, 723.15, 468.72,
 366.52, 513.45, 703.74, 421.34, 961.38]

# %%
def chamar_separador_lista(produtos,precos):
  for i in range(len(produtos)):
    if "BEB" in produtos[i]:
      prod_alc.append(produtos[i])
      price_alc.append(precos[i])
    else:
      if "TFA" in produtos[i]:
        prod_sup.append(produtos[i])
        price_sup.append(precos[i])
      else:
        itens_outros.append(produtos[i])
        price_outros.append(precos[i])

# programa principal
prod_alc = [] # listas vazias
price_alc = []
prod_sup = []
price_sup = []
itens_outros = []
price_outros = []

chamar_separador_lista(produtos,precos)

print(f'Produtos \"BEB\" alcoolicos: {prod_alc}')
print(f'Precos \"BEB\" alcoolicos: {price_alc}\n')
print(f'Produtos \"TFA\": {prod_sup}')
print(f'Precos \"TFA\": {price_sup}\n')
print(f'Produtos \"Outros\": {itens_outros}')
print(f'Precos \"Outros\": {price_outros}\n')
# Out:
# Produtos "BEB" alcoolicos: ['BEB21365', 'BEB31623', 'BEB73344', 'BEB80694', 'BEB19495', 'BEB97471', 'BEB62362', 'BEB85146', 'BEB48898', 'BEB79496', 'BEB15385', 'BEB24213', 'BEB56262', 'BEB75073']
# Precos "BEB" alcoolicos: [1256.34, 729.27, 432.89, 1191.3, 1165.32, 1232.68, 1112.44, 1150.78, 544.38, 949.14, 468.72, 366.52, 513.45, 961.38]
#
# Produtos "TFA": ['TFA23962', 'TFA64715', 'TFA69555', 'TFA56743', 'TFA44968', 'TFA20079', 'TFA14792', 'TFA78043', 'TFA27311', 'TFA17715', 'TFA19947', 'TFA58799']
# Precos "TFA": [917.65, 1050.26, 414.36, 904.9, 640.14, 457.95, 1040.62, 781.12, 1265.35, 575.2, 758.28, 398.22]
#
# Produtos "Outros": ['beb46275', 'BSA45510', 'CAR75448', 'CAR23596', 'CAR13490', 'BSA62419', 'BSA11769', 'BSA33484', 'CAR38417', 'CAR94811', 'BSA59251', 'BSA96915', 'CAR53454']
# Precos "Outros": [1258.69, 1077.77, 379.92, 1201.62, 1206.15, 1252.72, 421.77, 1059.19, 1043.73, 662.56, 723.15, 703.74, 421.34]

# %%
# Parte 2: Passar como argumento também o código da categoria.
# Pequeno ajuste para atender 100% o pedido no código.

def chamar_separador_lista(produtos,precos,str_cod_cat):
  for i in range(len(produtos)):
    if str_cod_cat in produtos[i]:
      nova_lista_prod.append(produtos[i])
      nova_lista_preco.append(precos[i])

# programa principal
nova_lista_prod = [] # listas vazias
nova_lista_preco = []
str_cod_cat = input("Informe o código da categoria [BEB ou TFA]: ")

chamar_separador_lista(produtos,precos,str_cod_cat)

print(f'Produtos \"{str_cod_cat}\": {nova_lista_prod}')
print(f'Precos \"{str_cod_cat}\": {nova_lista_preco}\n')
# Out:
# Informe o código da categoria [BEB ou TFA]: TFA
# Produtos "TFA": ['TFA23962', 'TFA64715', 'TFA69555', 'TFA56743', 'TFA44968', 'TFA20079', 'TFA14792', 'TFA78043', 'TFA27311', 'TFA17715', 'TFA19947', 'TFA58799']
# Precos "TFA": [917.65, 1050.26, 414.36, 904.9, 640.14, 457.95, 1040.62, 781.12, 1265.35, 575.2, 758.28, 398.22]

# %% [markdown]
# Ex.15. Extras: Criar um programa que cadastre em uma lista todos os produtos digitados pelo usuário. Transformar esse programa numa função chamada caditem que crie a mesma lista. Fazer com que este programa trate o texto inserido (strip, casefold, trocar espaços duplos por espaços simples).

# %%
# def caditem():
#   lista_15.append()

lista_15 = [] # lista vazia
# while True:
  # Eu poderia escrever todos os itens da lista e usar o .split() para me dar uma lista separada
  # lista_15.append(input("Digite um item: ").strip(" "))
lista_15 = input("Digite um item: ").split()
print(lista_15)

# maca uva banana abacaxi mirtilo
# Vou recomeçar e fazer conforme ele pediu ...
# Out:
# Digite um item: maca uva banana abacaxi mirtilo
# ['maca', 'uva', 'banana', 'abacaxi', 'mirtilo']

# %% [markdown]
# Ex.15. Extras: Criar um programa que cadastre em uma lista todos os produtos digitados pelo usuário. Transformar esse programa numa função chamada caditem que crie a mesma lista. Fazer com que este programa trate o texto inserido (strip, casefold, trocar espaços duplos por espaços simples).

# %%
# def caditem():
#   lista_15.append()

lista_15 = [] # lista vazia
while True:
  x = input("Digite o item: [pressione enter para sair.] ")
  if x != "":
    x = x.strip() # remove espaços em branco (ou caracteres específicos) do início e do fim de uma string
    x = x.casefold() # converte strings para minúsculas de forma agressiva
    x = x.replace("  "," ") # utilizado para substituir partes de uma string por um novo valor
    lista_15.append(x)
  else:
    break

print(lista_15)
# Out:
# Digite o item: [pressione enter para sair.]Uva
# Digite o item: [pressione enter para sair.]Morango
# Digite o item: [pressione enter para sair.]Laranja Pera
# Digite o item: [pressione enter para sair.]
# ['uva', 'morango', 'laranja pera']

# %%
def caditem():
  while True:
    x = input("Digite o item: [pressione enter para sair.] ")
    if x != "":
      x = x.strip() # remove espaços em branco (ou caracteres específicos) do início e do fim de uma string
      x = x.casefold() # converte strings para minúsculas de forma agressiva
      x = x.replace("  "," ") # utilizado para substituir partes de uma string por um novo valor
      lista_15.append(x)
    else:
      break

# programa principal
lista_15 = [] # lista vazia
caditem()
print(lista_15)
# Out:
# Digite o item: [pressione enter para sair.] Maca
# Digite o item: [pressione enter para sair.]   UVA
# Digite o item: [pressione enter para sair.] LARANJA  perA
# Digite o item: [pressione enter para sair.]
# ['maca', 'uva', 'laranja pera']
